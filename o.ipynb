# %%
import re
from datetime import datetime, timedelta

date_str = '1 minute ago'

match_hour = re.match(r'(\d+)\s+hour[s]?\s+ago', str(date_str))
match_minute = re.match(r'(\d+)\s+minute[s]?\s+ago', str(date_str))
if match_hour:
    hours_ago = int(match_hour.group(1))
    date = datetime.now() - timedelta(hours=hours_ago)
    print(date)
elif match_minute:
    minutes_ago = int(match_minute.group(1))
    date = datetime.now() - timedelta(minutes=minutes_ago)
    print(date)
# Out:
# 2024-09-17 09:34:58.615992

# %%
current_url = 'https://www.latimes.com/search?q=euro&s=1&p=10'
url_preffix, url_suffix = current_url.rsplit('&', 1)
if url_suffix.startswith('p='):
    next_url = url_preffix + '&p=' +  str(int(url_suffix.rsplit('=', 1)[-1])+1)
else:
    next_url = current_url + '&p=2'

next_url
# Out:
# 'https://www.latimes.com/search?q=euro&s=1&p=11'

# %%
url_preffix, url_suffix = current_url.rsplit('&', 1)
print(url_preffix)
print(url_suffix)
# Out:
# https://www.latimes.com/search?q=euro&s=1
# p=3

# %%
from topics_dict import topics_dict

url = 'https://www.latimes.com/search?q=euro&s=1'
url_0, url_1 = url.rsplit('&', 1)
print(url_0)
print(url_1)

topic = "Lakers"

url_topic = url_0 + '&' + topics_dict[topic] + '&' + url_1
url_topic
# Out:
# https://www.latimes.com/search?q=euro
# s=1
# 'https://www.latimes.com/search?q=euro&f0=00000168-86b0-d5d8-a76d-eff9710b0000&s=1'

# %%
"World &; Nation":
"Business":
"Entertainment &; Arts":
"Travel &; Experiences":
"Sports":
"California":
"Archives":
"Politics":
"Books":
"Movies":
"Music":
"Soccer":
"Science &; Medicine":
"Food":
"Olympics":
"Opinion":
"Autos":
"Technology and the Internet":
"Television":
"Money &; Company":
"Obituaries":
"Hockey":
"World Now":
"Real Estate":
"Culture Monster Blog":
"High School Sports":
"Awards":
"Recipes":
"Lakers":
"Sports Now":
"Lifestyle":
"Babylon &; Beyond":
"Hollywood Inc." :
"Top of the Ticket":
"Opinion L.A." :
"Technology Blog":
"Pop &; Hiss":
"Clippers":
"Company Town Blog":
"UCLA Sports":
"L.A. Unleashed":
"All the Rage":
"Daily Dish":
"Show Tracker":
"24 Frames":
"Jacket Copy":
"Climate &; Environment":
"USC Sports":
"Booster Shots":
" La Plaza":
"Angels":
"L.A. at Home":
"Letters to the Editor":
"Olympics Blog":
"Ministry of Gossip":
"Greenspace":
"Dodgers":
"Nation Now":
"De Los":
"Hero Complex Blog":
"Los Angeles County":
"Housing &; Homelessness":
"Afterword":
"Image":
"The Big Picture":
"L.A. Now":
"Varsity Times Insider":
"Updates":
"Readers Representative":
"B2B Publishing":
"For the Record":
"Orange County":
"Hot Property: The Design Issue – 40 Under 40":
"Company News":
"Orange County":
"Bit Player":
"LAFC":
"Politi-Cal":
"Awards Tracker":
"Angel City FC":
"2007 California Wildfires":
"Surrounding Counties":
"Business of Law Trends, Updates Visionaries and The In-House Counsel Awards Recap":
"L.A. Influential":
"Podcasts": 
"2023 C-Suite Trends, Updates and the CFO Leadership Awards Recap":
"Banking and Finance Trends, Updates and 2024 Visionaries":
"Chargers":
"Galaxy": 
"Rams":
"Special Supplements":
"2024 C-Suite Trends, Updates and the CFO Forum and Leadership Awards Recap":
"ADVISORS":
"Escapes. Travel. Adventure (ETA)" :
"Hot Property":
"About the Los Angeles Times":
"Las Vegas Guide":
"Los Angeles County Banking and Finance: Trends. Updates. Visionaries.":
